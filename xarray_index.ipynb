# %%
import xarray as xr

xr.set_options(display_expand_attrs=False, display_expand_data=False)

# %%
ds = xr.tutorial.load_dataset("air_temperature")
ds
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:  (lat: 25, time: 2920, lon: 53)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float64 31MB 241.2 242.5 243.5 ... 296.2 295.7
# Attributes: (5)

# %%
da = ds["air"]
da
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)> Size: 31MB
# 241.2 242.5 243.5 244.0 244.1 243.9 ... 297.9 297.4 297.2 296.5 296.2 295.7
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Attributes: (11)

# %%
np_array = ds["air"].data  # numpy array
np_array.shape
# Out:
# (2920, 25, 53)

# %%
np_array[1, 0, 0]
# Out:
# 242.1

# %%
print(len(da.data))
# Out:
# 2920

# %%
da.sel(lat=25, lon=210).plot();

# %%
import numpy as np
shuobinArray = xr.DataArray(data = [[1,2,3], [2,3,5]], 
             dims=['d1', 'd2'], coords={"d1": [1,2],
                                        "d2":[3,3,3]}, attrs={"des": "Good good study"})

# %%
xr.Dataset(
    data_vars= {
        "shuobinArray": shuobinArray,
        "jack": xr.DataArray()
    }
)
# Out:
# <xarray.Dataset> Size: 52B
# Dimensions:       (d1: 2, d2: 3)
# Coordinates:
#   * d1            (d1) int32 8B 1 2
#   * d2            (d2) int32 12B 3 3 3
# Data variables:
#     shuobinArray  (d1, d2) int32 24B 1 2 3 2 3 5
#     jack          float64 8B nan
