# %%
import skimage as ski
from skimage import io
from skimage.exposure import histogram
from skimage.segmentation import quickshift, slic

coins = ski.data.coins()
hist, hist_centers = ski.exposure.histogram(coins)

# %%
io.imshow(coins)

# %%
edges = ski.feature.canny(coins / 255.)
io.imshow(edges)

# %%
import scipy as sp
fill_coins = sp.ndimage.binary_fill_holes(edges)
io.imshow(fill_coins)

# %%
import numpy as np
markers = np.zeros_like(coins)
markers[coins < 30] = 1
markers[coins > 150] = 2
io.imshow(markers)
# Out:
# d:\Projects\VsCode\Python\img_processing_system\.conda\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
from skimage.segmentation import slic
from skimage.data import astronaut
img = astronaut()
print(type(img))
print(img.shape)
io.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# (512, 512, 3)

# %%
segments = slic(img, n_segments=50, compactness=1)
io.imshow(segments)

# %%
segments = slic(img, n_segments=50, compactness=10)
io.imshow(segments)

# %%
segments = slic(img, n_segments=50, compactness=100)
io.imshow(segments)
